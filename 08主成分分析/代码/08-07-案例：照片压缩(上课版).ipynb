# %% [markdown]
# # 案例：照片压缩

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### 读取照片

# %%
img=mpimg.imread("data/jjq.jpg")

# %% [markdown]
# ### 显示照片

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ### 查看照片维度

# %%
img.shape
# Out:
# (800, 600, 3)

# %% [markdown]
# ### 把照片变成一个二维数组

# %%
X = img.reshape(1200,1200)

# %%
X
# Out:
# array([[-0.65158734,  0.26402337,  0.94608856, ..., -0.64756895,
#          0.28112662,  0.96089318],
#        [-0.65158734,  0.26402337,  0.94608856, ..., -0.64756895,
#          0.28112662,  0.96089318],
#        [-0.65158734,  0.26402337,  0.94608856, ..., -0.64756895,
#          0.28112662,  0.96089318],
#        ...,
#        [-0.2076543 , -0.58135238, -0.50179511, ..., -0.33043172,
#         -0.75318539, -0.55720635],
#        [-0.29089175, -0.73164141, -0.57074196, ..., -1.0612262 ,
#         -1.71361797, -1.40515384],
#        [-0.73482479, -1.29522524, -1.05336985, ..., -1.14395766,
#         -1.80596725, -1.55559613]])

# %% [markdown]
# ### 数据标准化

# %%
X = StandardScaler().fit_transform(X)

# %% [markdown]
# ### 使用PCA降维

# %%
model = PCA(n_components=40)
Z = model.fit_transform(X)

# %%
Z.shape
# Out:
# (1200, 40)

# %%
print("贡献比=",np.sum(model.explained_variance_ratio_))
# Out:
# 贡献比= 0.9773890540166301

# %%
model.explained_variance_ratio_
# Out:
# array([0.32719341, 0.16866854, 0.13180012, 0.12414515, 0.04718015,
#        0.03767961, 0.01961962, 0.01856793, 0.01383602, 0.01170283,
#        0.00830703, 0.00744285, 0.00609401, 0.00532511, 0.00459304,
#        0.00426891, 0.00352631, 0.00319815, 0.00272192, 0.00255017,
#        0.0023687 , 0.0022545 , 0.00215952, 0.00207097, 0.00200807,
#        0.00193542, 0.0018211 , 0.00148068, 0.00143651, 0.00140197,
#        0.00136512, 0.00116256, 0.00114696, 0.00108579, 0.00106318,
#        0.00096087, 0.00085435, 0.00082297, 0.00080161, 0.00076823,
#        0.00073931, 0.00072447, 0.00071395, 0.00068887, 0.0006294 ,
#        0.00061775, 0.00059284, 0.00055245, 0.00053778, 0.00052197])

# %% [markdown]
# ### 数据还原

# %%
X_rec = model.inverse_transform(Z)
X_rec = X_rec.reshape(800,600,3)

# %% [markdown]
# ### 显示还原后的照片

# %%
plt.imshow(X_rec)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
